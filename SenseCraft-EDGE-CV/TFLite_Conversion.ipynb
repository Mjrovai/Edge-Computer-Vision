# %% [markdown]
# # TFLite to Arm Ethus-U NPU  Conversion model
# by Marcelo Rovai

# %%
# !pip install ethos-u-vela
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.2/394.2 kB 4.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for ethos-u-vela: filename=ethos_u_vela-3.10.0-cp310-cp310-linux_x86_64.whl size=591991 sha256=d6288740f9cc23cde0c9b3852a7777c642005292e8f07d2fedf50aa5a5d88433
#   Stored in directory: /root/.cache/pip/wheels/d4/77/a1/6e947bf8bbf4f6e9057a3b66eb3635c24b48552dda73bb2567
# Successfully built ethos-u-vela
# ...

# %%
# !vela --version
# Out:
# 3.10.0

# %% [markdown]
# ## Upload the Int8 quantized .tflite ![colab-upload_model.png](data:image/png;base64,...)

# %%
# !ls
# Out:
# ei-periquito-vs-robot-int8.tflite  sample_data

# %% [markdown]
# ## Make the Conversion

# %%
# !vela ei-periquito-vs-robot-int8.tflite --accelerator-config ethos-u55-64
# Out:
# ...
#
# Network summary for ei-periquito-vs-robot-int8
# Accelerator configuration                Ethos_U55_64
# System configuration                 internal-default
# Memory mode                          internal-default
# Accelerator clock                                 500 MHz
# Design peak SRAM bandwidth                       4.00 GB/s
# Design peak Off-chip Flash bandwidth             0.50 GB/s
#
# Total SRAM used                                146.05 KiB
# Total Off-chip Flash used                      185.77 KiB
#
# CPU operators = 0 (0.0%)
# NPU operators = 96 (100.0%)
#
# Average SRAM bandwidth                           1.01 GB/s
# Input   SRAM bandwidth                           0.71 MB/batch
# Weight  SRAM bandwidth                           0.31 MB/batch
# Output  SRAM bandwidth                           0.51 MB/batch
# Total   SRAM bandwidth                           1.57 MB/batch
# Total   SRAM bandwidth            per input      1.57 MB/inference (batch size 1)
#
# ...

# %% [markdown]
# ## Download the converted model

# %% [markdown]
# ![image.png](data:image/png;base64,...)
